# %%
# word2vec, news, ndcg: word2vec_genre_news_vector_size_50_window_size_10_iteration_number_1000.model, 0.006004818330171734
# word2vec, romance, ndcg: word2vec_genre_romance_vector_size_50_window_size_2_iteration_number_1000.model, 0.009880989624656998

# word2vec, news, map:  word2vec_genre_news_vector_size_50_window_size_5_iteration_number_1000.model, 0.0024352157228869553
# word2vec, romance, map: word2vec_genre_romance_vector_size_50_window_size_2_iteration_number_1000.model, 0.00333120538649385

# %%
# tfidf, news, ndcg: 0.0009177470542896186
# tfidf, romance, ndcg: 0.003698600359002533

# tfidf, news, map: 0.00023561507936507934
# tfidf, romance, map: 0.0013868796463733174

# %%
import matplotlib.pyplot as plt

plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = [f'C{i}' for i in range(1, 5)]
y_pos = np.arange(len(objects))
performance = [0.006004818330171734, 0.0009177470542896186, 0.009880989624656998, 0.003698600359002533]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('nDCG')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = [f'C{i}' for i in range(1, 5)]
y_pos = np.arange(len(objects))
performance = [0.0024352157228869553, 0.00023561507936507934, 0.00333120538649385, 0.0013868796463733174]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('map')

plt.show()

# %%
from tabulate import tabulate

print(tabulate({'First Name': ['John', 'Mary'], 'Last Name': ['Smith', 'Jane', 'Doe'], 'Age': [39, 25, 28]}, headers="keys", tablefmt='fancy_grid'))
# Out:
# ╒══════════════╤═════════════╤═══════╕
# │ First Name   │ Last Name   │   Age │
# ╞══════════════╪═════════════╪═══════╡
# │ John         │ Smith       │    39 │
# ├──────────────┼─────────────┼───────┤
# │ Mary         │ Jane        │    25 │
# ├──────────────┼─────────────┼───────┤
# │              │ Doe         │    28 │
# ╘══════════════╧═════════════╧═══════╛
