# %%
success_1_average = 0.2856095056476456
success_5_average = 0.4732286929734487
success_10_average = 0.5173830130555963

# %%
import matplotlib.pyplot as plt

s_at_k = ['s@1', 's@5', 's@10']
s_at_k_average = [success_1_average, success_5_average, success_10_average]

plt.bar(s_at_k, s_at_k_average)
plt.title('s@k Average')
plt.xlabel('s@k')
plt.ylabel('Average')
plt.show()

# %%
wordnet_words = 147306
birkbeck_words = 12231
birkbeck_words_unique = 6817

# %%
s_at_k = ['wordnet', 'birkbeck', 'birkbeck unique']
s_at_k_average = [wordnet_words, birkbeck_words, birkbeck_words_unique]

plt.bar(s_at_k, s_at_k_average)
plt.title('Words Count')
plt.xlabel('Source')
plt.ylabel('Count')
plt.show()

# %%
word_1 = 'prepearing'
word_1_similar = [('rehearing', 2), ('repeating', 2), ('pampering', 3), ('preceding', 3), ('propelling', 3), ('prospering', 3), ('rearing', 3), ('releasing', 3), ('repelling', 3), ('revealing', 3)]

word_2 = 'acount'
word_2_similar = [('account', 1), ('amount', 1), ('count', 1), ('about', 2), ('around', 2), ('accent', 2), ('aclant', 2), ('acorn', 2), ('arouet', 2), ('aunt', 2)]

word_3 = 'symthoms'
word_3_similar = [('lymphoma', 3), ('symons', 3), ('symphony', 3), ('symptom', 3), ('lymphoid', 4), ('sotho', 4), ('sumptuous', 4), ('symphonic', 4), ('xanthous', 4), ('somehow', 4)]

word_4 = 'has'
word_4_similar = [('as', 1), ('aas', 1), ('das', 1), ('eas', 1), ('fas', 1), ('gas', 1), ('ha', 1), ('hag', 1), ('haj', 1), ('hals', 1)]

word_5 = 'inconveniencies'
word_5_similar = [('inconvenience', 2), ('conveniences', 3), ('inconvenient', 4), ('inconveniently', 4), ('convenience', 4), ('inconsequence', 5), ('incontinence', 5), ('convenient', 6), ('inconsequential', 6), ('unconvinced', 6)]

# %%
with open('./elapsed/elapsed_converted.txt', 'r') as handle:
    lines = handle.readlines()

seconds = list()
for line in lines:
    seconds.append(int(line))


print(seconds)
job = range(len(seconds))

plt.plot(job, seconds)
plt.title('Total Duration of Each Job')
plt.xlabel('Seconds')
plt.ylabel('Job ID')

plt.show()
# Out:
# [582, 637, 624, 571, 529, 1186, 480, 528, 575, 627, 682, 687, 623, 547, 546, 557, 702, 565, 423, 652, 567, 677, 1217, 614, 598, 540, 492, 577, 536, 520, 635, 610, 569, 532, 526, 459, 515, 533, 572, 636, 579, 719, 726, 700, 686, 564, 337, 548, 727, 629, 595, 435, 676, 706, 707, 513, 642, 661, 633, 507, 1218, 574, 655, 523, 553, 566, 519, 599, 630, 718, 419, 516, 576, 641, 456, 625, 489, 518, 556, 580, 1102, 437, 1243, 594, 479, 521, 478, 1099, 589, 538, 510, 632, 544, 665, 568, 1231, 1240, 603, 649, 476, 511, 561, 672, 662, 674, 721, 517, 535, 588, 551, 638, 534, 335, 504, 508, 541, 466, 527, 505, 626, 472, 455, 495, 491, 549, 689, 600, 619, 692, 539, 591, 463, 1221, 583, 688, 552, 524, 650, 502, 597, 705, 601, 604, 605, 608, 590, 651, 573, 584, 648, 525, 509, 543, 522, 500, 593, 555, 695, 587, 458, 570, 643, 668, 581, 496, 645, 663, 506, 585, 724, 542, 559, 679, 1233, 693, 578, 691, 558, 545, 602, 467, 531, 498, 611, 712, 757, 671, 656, 667, 586]
